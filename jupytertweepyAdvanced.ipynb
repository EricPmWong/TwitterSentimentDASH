# %% [markdown]
# ## JupyterNotebook Version of tweepyAdvanced.py

# %% [markdown]
# note: This notebook does not execute and will not work unless Plotly, Twilio and Twitter Developer Credentials are found

# %% [markdown]
# ### Imports

# %%
#Statitstics and Visuals
import numpy as np
import pandas as pd
import time
import datetime
#import matplotlib.pyplot as plt
#import matplotlib.animation as animation

#Tweepy and Twitter Imports
from tweepy import Stream, OAuthHandler, StreamListener
from tweepy.streaming import StreamListener
import json

#tokenizer
from nltk.corpus import stopwords
#from sklearn.feature_extraction.text import CountVectorizer
from collections import Counter

#Sentiment Analysis
from textblob import TextBlob #More Acccurate
#import nltk 
import re

#Dashboard
import plotly 
import plotly.plotly as py
#import plotlywrapper as pw
#import dash
from dash.dependencies import Output, Input
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
import plotly.tools as tls

#from statsmodels.tsa.arima_model import ARIMA
from urllib3.exceptions import ProtocolError

# %% [markdown]
# ### Variable Declaration (These are globalized by class later)

# %%
#########################################################
#Input brand of interest here
brand = 'gucci'
##########################################################
## SET MESSAGE NEGATIVE TWEET TOLERANCE. Graphs will not change without resets
tolerance = 10 
##########################################################

# %% [markdown]
# ### Developer Credentials

# %%
# Tokens for Twitter These are my developer keys please do not abuse thanks
API = 'sFb8T5BX4PAc50iCj1RMnty8m'
APIKEY = 'b4Eawn17wX2cf2sjBAmkEn8RFlQFezhdakIRcl8mbJKlkqjiZ1'
ACC = '1087768519268282370-TK5Gp6EfuFTj4WlLVhNRujzVjzOlgY'
ACCKEY = 'nC5z5yiLweU17qDtrdwrsQmtAJiLUb2915c2IHGAkngYS'
#Plotly Credentials
stream_ids = tls.get_credentials_file()['stream_ids']
print (stream_ids)

# %% [markdown]
# ### Defining Variables

# %%
#Global Variables predefined
#Changing Vars
positive=0
negative=0
neutral=0
positive_var = 0
negative_var = 0
neutral_var = 0
#Persistent Vars
count = 0
timex = [] 
timeypos = [] 
timeyneg = [] 
timeyneu = [] 
timeysent = [] 
tokens=[]
tokenstop =[]
Tx=[]
Ty=[]
posvar = []
negvar = []
neuvar = []
arimap = []
ariman = []
#Text messaging condition
sms = 0

# %% [markdown]
# ### Plotly Streams and settings (Uses above plotly credentials)

# %%
#Creating Plotly Streams
    # Absolute Senitment
stream1 = plotly.graph_objs.scatter.Stream(token =stream_ids[0])
stream2 = plotly.graph_objs.scatter.Stream(token =stream_ids[1])
stream3 = plotly.graph_objs.scatter.Stream(token =stream_ids[2])
    # Percent Sentiment
stream4 = plotly.graph_objs.scatter.Stream(token =stream_ids[3])
stream5 = plotly.graph_objs.scatter.Stream(token =stream_ids[4])
stream6 = plotly.graph_objs.scatter.Stream(token =stream_ids[5])
    # Live tweet
#stream7 = plotly.graph_objs.bar.Stream(token =stream_ids[6])
    #Word Count
stream8 = plotly.graph_objs.bar.Stream(token =stream_ids[7])
    #Heatmap 
#stream9 = plotly.graph_objs.heatmap.Stream(token =stream_ids[8])
    #Positive/Negative Rolling Mean 3
stream10 = plotly.graph_objs.scatter.Stream(token =stream_ids[9])
#stream11 = plotly.graph_objs.scatter.Stream(token =stream_ids[10])
stream12 = plotly.graph_objs.scatter.Stream(token =stream_ids[11])
stream13 = plotly.graph_objs.scatter.Stream(token =stream_ids[12])
stream14 = plotly.graph_objs.scatter.Stream(token =stream_ids[13])

# Stream objects
s1 = py.Stream(stream_ids[0])
s2 = py.Stream(stream_ids[1])
s3 = py.Stream(stream_ids[2])
s4 = py.Stream(stream_ids[3])
s5 = py.Stream(stream_ids[4])
s6 = py.Stream(stream_ids[5])
#s7 = py.Stream(stream_ids[6])
s8 = py.Stream(stream_ids[7])
#s9 = py.Stream(stream_ids[8])
s10 = py.Stream(stream_ids[9])
#s11 = py.Stream(stream_ids[10])
s12 = py.Stream(stream_ids[11])
s13 = py.Stream(stream_ids[12])
s14 = py.Stream(stream_ids[13])

# %% [markdown]
# ### Plotly Graph of Stacked sentiment analyzed tweets

# %%
#Plotly Line Graph 
trace1 = go.Scatter(name = 'Negative', x=timex, y=timeyneg, mode='lines+markers', stream = stream1, fill = 'tozeroy',  stackgroup='one', text="Negative",)
trace2 = go.Scatter(name = 'Neutral', x=timex, y=timeyneu, mode='lines+markers', stream = stream2, fill = 'tonexty',   stackgroup='one', text="Neutral",)
trace3 = go.Scatter(name = 'Positive',x=timex, y=timeypos, mode='lines+markers', stream = stream3, fill = 'tonexty',   stackgroup='one', text="Positive",)
data = [trace1, trace2, trace3]
layout = {'title':(str(brand)+" Sentiment Analysis"),
'shapes': [
{'type': 'line',
'xref': 'paper',
'x0': 0,
'y0': tolerance,
'x1': 1, #datetime.datetime.now().strftime('%M:%S'),
'y1': tolerance,
'line': {
'color': 'red',
'width': 4,
'dash': 'dashdot'}}
    ],
    'annotations' : [
        dict(
            x=.05,
            y=tolerance - 1,
            xref='paper',
            yref='y',
            text='Text Warning Enabled',
            showarrow=False,
            font=dict(
                family='Courier New, monospace',
                size=16,
                color='#ffffff'
            ),
            align='center',
            arrowhead=2,
            arrowsize=1,
            arrowwidth=2,
            arrowcolor='#636363',
            ax=20,
            ay=-30,
            bordercolor='#c7c7c7',
            borderwidth=2,
            borderpad=4,
            bgcolor='red',
            opacity=1
        )
    ]
}
fig = dict(data=data, layout=layout)

# %% [markdown]
# ### Plotly Normalized Percentage Line Graph Stacked

# %%
#Line Graph Percentage
trace4 = go.Scatter(name = 'Negative percent', x=timex, y=timeyneg, mode='lines+markers', stream = stream4, fill = 'tozeroy',  stackgroup='one', text="Negative", groupnorm='percent',  )
trace5 = go.Scatter(name = 'Neutral percent', x=timex, y=timeyneu, mode='lines+markers', stream = stream5, fill = 'tonexty',   stackgroup='one', text="Neutral",)
trace6 = go.Scatter(name = 'Positive percent',x=timex, y=timeypos, mode='lines+markers', stream = stream6, fill = 'tonexty',   stackgroup='one', text="Positive",)
datap = [trace4, trace5, trace6]
layoutp = go.Layout(title=(str(brand)+" Sentiment Analysis Normalized"))
figpercent = dict(data=datap, layout=layoutp)

# %% [markdown]
# ### Plotly Tokenized Word Count Graph

# %%
#Toenized Word Count
trace8 = go.Bar(x= Tx, y=Ty,  stream = stream8, orientation='h')
datat = [trace8]
layoutt = go.Layout(title=(str(brand)+" Common words"))
fighist = dict(data=datat, layout=layoutt)

# %% [markdown]
# ### Plolty Positive Tweet Graph

# %%
#Positive Tweet Moving Average
trace10 = go.Scatter(name = 'Negative', x=timex, y=negvar, mode='lines+markers', stream = stream10, text="Negative", line =dict(color ='blue', ))
trace13 = go.Scatter(name = 'Rolling Mean 3', x=timex, y=ariman, mode='lines+markers', stream = stream13, text="Predicted", line =dict(color = ('red'),
        width = 4,
        dash = 'dot'))
layout1 = go.Layout(title = (str(brand)+" Negative Tweets per minute"))
figminneg = dict(data=[trace10, trace13], layout=layout1)

# %% [markdown]
# ### Plotly Neagtive Tweet Graph

# %%
#Negative Tweet Moving Average
trace12 = go.Scatter(name = 'Positive',x=timex, y=posvar, mode='lines+markers', stream = stream12,  text="Positive", line =dict(color='green'))
trace14 = go.Scatter(name = 'Rolling Mean 3', x=timex, y=arimap, mode='lines+markers', stream = stream14, text="Predicted", line =dict(color = ('red'),
        width = 4,
        dash = 'dot'))
layout2 = go.Layout(title = (str(brand)+" Positive Tweets per minute"))
figminpos = dict(data=[trace12, trace14], layout=layout2)

# %% [markdown]
# ### Defining Listener which takes it stream and interprets
# ### Applys tokenizer, sentiment, moving average, text messaging, writing data for plotly streams, timestamping etc

# %%
#########################################################################################
#Creates a class of filters, data modificaitons, etc to create twitter data
class stdOUTlistener(StreamListener):
    
#Grabbing data if not error.
    def on_data(self,data):
        
        #Sends a text message at negativity tolerance rate. See alert_sms documentation. 
        global sms
        for x in timeyneg:
            if x >= tolerance and sms == 0:
                import alert_sms
                sms += 1
    
#Try used in case of Key error
        try:
            #Set globals
            global positive
            global negative  
            global neutral
            #global combined  
            global count
            #global total
            global text
            global positive_var
            global negative_var
            global neutral_var
            global posvar
            global negvar
            global neuvar
            global arimap 
            global ariman
            global Tx
            global Ty

            

            #Count 1 per tweet pull, 1 pull can contain 2-3 tweets
            count += 1
            print("TWEET PULL", count)

            
            
            #Data Loading from json
            all_data=json.loads(data)
            tweet=all_data["text"]
            
            #Tweet Cleaning 
            tweet=' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) |(\w+:\/\/\S+',’)", " ", tweet).split())
            blob=TextBlob(tweet.strip())
            
            #Conducts Sentiment Analysis per tweet
            for sen in blob.sentences:
                #Create time stamps for X variables
                global initime
                t= datetime.datetime.now().strftime('%M:%S')

                print(t)
                print(sen)
                # Positive Tweet Threshold is higher. Due to many false positives
                sentiment = sen.sentiment.polarity
                print(sentiment)
                if sentiment > 0.3:
                    positive += 1
                    positive_var += 1
                    print("pos")
                #Negative tweets have a higher threshold. 
                #Vernacular causes noises and positive tweets were False positives.(of Negatives
                elif sentiment < -.01:
                    negative += 1
                    negative_var += 1
                    print("neg")
                else:
                    neutral +=1
                    neutral_var += 1
                    print("neutral")

                #Tokenizes words for graph
                tokens.extend([word for word in blob.words if word not in stopwords.words('english') and word not in "RT" and word not in "’" and word not in "," and word not in "https" and word not in str(brand) and word not in "I" and word not in "Gucci"])
                tokenstop = Counter(tokens)
                Tx = [x[1] for x in tokenstop.most_common(30)]
                Ty = [x[0] for x in tokenstop.most_common(30)]
                #print(Tx, Ty)
                s8.write(dict(x=Tx, y=Ty))


            # If TIME is not repeated, execute drawing to plotly
            if t not in timex:
                #Adds the time to X var
                timex.append(t)
                #Appending info to array for graphing
                posvar.append(positive_var)
                negvar.append(negative_var)
                neuvar.append(neutral_var)
                #Variables for ABS. and Percentage Graph
                timeypos.append(positive) 
                timeyneg.append(negative)
                timeyneu.append(neutral) 
                #totalpnn.append(total)
                #total += (positive+negative+neutral)
                # #text.append(sen)
                #combined += sen.sentiment.polarity
                #ARIMA 
                #Changed in favor of rolling mean manually calculated due to CPU overhead

                #3 day Rolling Mean calculations 
                try:
                #Calculating moving average instead
                    arimap.append(np.mean([posvar[-3],posvar[-2], posvar[-1]]))
                    ariman.append(np.mean([negvar[-3],negvar[-2], negvar[-1]]))
                    #pos
                    #modelp = ARIMA(posvar,order=(0,0,2))
                    #modelp_fit = modelp.fit(disp=0)
                    #predpos = modelp_fit.predict().astype(float)
                    #predposap = predpos[-1]
                    #arimap.append(predposap)
                    #print("Positve Arima",arimap)
                    #neg
                    #modeln = ARIMA(negvar ,order=(0,0,2))
                    ##modeln_fit = modeln.fit(disp=0)
                    #predneg = modeln_fit.predict().astype(float)
                    #prednegap = predneg[-1]
                    #ariman.append(prednegap)
                    #print("Negative Arima",ariman)
                except: 
                    arimap.append(0.00)
                    ariman.append(0.00)

                #Required Plotly channels to update graph
                s1.write(dict(x=timex, y=timeyneg))
                s2.write(dict(x=timex, y=timeyneu))
                s3.write(dict(x=timex, y=timeypos))
                #Nomralized Percentages
                s4.write(dict(x=timex, y=timeyneg))
                s5.write(dict(x=timex, y=timeyneu))
                s6.write(dict(x=timex, y=timeypos))
                #Commons Words Tokenizer
                
                #Negative Posts w/Arima
                s10.write(dict(x=timex, y=negvar))
                s13.write(dict(x=timex, y=ariman))
                #Positive Posts w/Arima
                s12.write(dict(x=timex, y=posvar))
                s14.write(dict(x=timex, y=arimap))

                #Unused Streams
                #s11.open()
                #s11.write(dict(x=timex, y=neuvar))
                #s9.open()
                #s9.write(dict(x=timex, y=timeysent))
                #s7.open()
                #s7.write(dict(x=, y)))


                #Print Indicators for testing
                #print("time", t)
                #print(blob)
                #print("LABELED AS ", sen.sentiment.polarity)
                #print("pos", positive)
                #print("negs", negative)
                #print("neutral", neutral)
                #print("combined sent", compound)
                #print(sentiment)
                #print(total)
                #print(totalpnn)
                #Resets vars
                #Reset Sentiment to 0 for each pull
                sentiment = 0
                #Resets for next time interval to replot
                positive_var = 0
                neutral_var = 0
                negative_var = 0

                print()

            #Executes same code if time stamp is same
            else:
                for sen in blob.sentences:
                    print(sen)
                    #Low threshold most often tweets with pictures or mentions of product are
                    #positive from a marketing perspective. Gains more traction. 
                    sentiment = sen.sentiment.polarity
                    print(sentiment)
                    if sentiment > 0.01:
                        positive += 1
                        positive_var += 1
                        print("pos")
                    #Negative tweets have a higher threshold. 
                    #Vernacular causes noises and positive tweets were False positives.(of Negatives
                    elif sentiment < -.01:
                        negative += 1
                        negative_var += 1
                        print("neg")
                    else:
                        neutral +=1
                        neutral_var += 1
                        print("neutral")
                
        except:
            pass
            print('error in loop')

    def on_error(self, status):
        print(status)
        pass



######################################################################################

# %% [markdown]
# ### Tweepy/Twitter API Access authenticator

# %%
listener = stdOUTlistener()
auth = OAuthHandler(API, APIKEY)
auth.set_access_token(ACC, ACCKEY)

# %% [markdown]
# ### Opens Plotly Channels to be written

# %%
#Stacked sentiment absolute values
s1.open()
s2.open()
s3.open()
#Nomralized Percentages
s4.open()
s5.open()
s6.open()
#Commons Words Tokenizer
s8.open()
#Negative Posts w/Arima
s10.open()
s13.open()
#Positive Posts w/Arima
s12.open()
s14.open()

# %% [markdown]
# ### Creates stream and engages

# %%
stream = Stream(auth, listener)

# %%
while True:
    try:
        stream.filter(track=[brand], languages=["en"]);
        
    except (ProtocolError, AttributeError):
        continue
# Out:
# TWEET PULL 1
# 07:42
# RT cardio good for the heart https://t.co/pp9DZHzSVc
# 0.7
# pos
#
# TWEET PULL 2
# 07:43
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
#
# TWEET PULL 3
# 07:43
# RT This is disgusting Wtf is this!
# -0.8125
# neg
# 07:43
# Prada Gucci Moncler.. you are Cut in my eyes https://t.co/NOWeXYLOGr
# 0.0
# neutral
# RT This is disgusting Wtf is this!
# -0.8125
# neg
# Prada Gucci Moncler.. you are Cut in my eyes https://t.co/NOWeXYLOGr
# 0.0
# neutral
# TWEET PULL 4
# 07:43
# RT look at you....boy i invented you gucci tennis shoes....runnin from your issues
# 0.0
# neutral
# RT look at you....boy i invented you gucci tennis shoes....runnin from your issues
# 0.0
# neutral
# TWEET PULL 5
# 07:45
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
#
# TWEET PULL 6
# 07:45
# RT It’s 2019 when are we going to stop using stereotypes etc as marketing tactics As a Marketer/advertisier there is a tea…
# 0.0
# neutral
# RT It’s 2019 when are we going to stop using stereotypes etc as marketing tactics As a Marketer/advertisier there is a tea…
# 0.0
# neutral
# TWEET PULL 7
# 07:45
# RT Nah nigga’s face after that gucci flip flop line He’s hurt https://t.co/h802Kmtkxn
# 0.0
# neutral
# RT Nah nigga’s face after that gucci flip flop line He’s hurt https://t.co/h802Kmtkxn
# 0.0
# neutral
# TWEET PULL 8
# 07:46
# RT Oh yall knew Tip was gone have some words for Gucci😭 #FuckGucci https://t.co/ypFeXGTOD2
# 0.0
# neutral
#
# TWEET PULL 9
# 07:46
# RT So like with this Gucci sweater how is it even worn How does it stay up on your face Are there straps behind your ears B…
# -0.4
# neg
# RT So like with this Gucci sweater how is it even worn How does it stay up on your face Are there straps behind your ears B…
# -0.4
# neg
# TWEET PULL 10
# 07:47
# RT Nah nigga’s face after that gucci flip flop line He’s hurt https://t.co/h802Kmtkxn
# 0.0
# neutral
#
# TWEET PULL 11
# 07:48
# RT If y'all cancelling Gucci don't forget Moncler too ☺ https://t.co/x8QMovnBUF
# 0.0
# neutral
#
# TWEET PULL 12
# 07:48
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# pos
# TWEET PULL 13
# 07:49
# RT T.I Let’s boycott Gucci for 3 months Me knowing I never bought any Gucci in my life https://t.co/YGD23VWVFA
# 0.0
# neutral
#
# TWEET PULL 14
# 07:51
# RT T.I Let’s boycott Gucci for 3 months Me knowing I never bought any Gucci in my life https://t.co/YGD23VWVFA
# 0.0
# neutral
#
# TWEET PULL 15
# 07:51
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# pos
# TWEET PULL 16
# 07:56
# RT T.I Let’s boycott Gucci for 3 months Me knowing I never bought any Gucci in my life https://t.co/YGD23VWVFA
# 0.0
# neutral
#
# TWEET PULL 17
# 07:58
# RT Y’all really surprised at luxury brands past being racist and continuing into their current trends https://t.co/EDURK36dPS
# -0.049999999999999996
# neg
#
# TWEET PULL 18
# 07:59
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
#
# TWEET PULL 19
# 08:00
# And we are killing US financially spending millions at Gucci fendi etc and won’t even buy a 50 t shirt fr https://t.co/GrNvNEi0H9
# 0.0
# neutral
#
# TWEET PULL 20
# 08:00
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# pos
# TWEET PULL 21
# 08:01
# WHEN YOU BUY SHOE TRY : FOR 20 NIKE !!!!!!!!!!
# 0.0
# neutral
# 08:01
# GUCCI 500 + OR LOOK FOR ADDIDAS OR OTHER BRANDS !
# -0.15625
# neg
# 08:01
# YOU CAN https://t.co/he40D1v0vY
# 0.0
# neutral
#
# TWEET PULL 22
# 08:01
# RT Pyer moss Stella jean public school a coldwall want less essentials walled Bonner...........all black owned luxury bran…
# -0.1111111111111111
# neg
# RT Pyer moss Stella jean public school a coldwall want less essentials walled Bonner...........all black owned luxury bran…
# -0.1111111111111111
# neg
# TWEET PULL 23
# 08:03
# RT Gucci &amp Prada are the easiest boycotts of all time 99 of people like me get to keep doing what they were aready doing
# 0.0
# neutral
#
# TWEET PULL 24
# 08:05
# RT Lee took to Instagram to proclaim he is officially boycotting Prada and Gucci until they “hire some Black designers to be in…
# -0.16666666666666666
# neg
#
# TWEET PULL 25
# 08:06
# They been boycotting lmao
# 0.6
# pos
#
# TWEET PULL 26
# 08:08
# When Ariana said “look at you boy I invented you in gucci tennis shoes runnin from your issues I felt that
# 0.0
# neutral
#
# TWEET PULL 27
# 08:08
# RT “When You Just Bought Hella Gucci But They Canceled https://t.co/qJ2m2X5ox9
# 0.0
# neutral
# RT “When You Just Bought Hella Gucci But They Canceled https://t.co/qJ2m2X5ox9
# 0.0
# neutral
# TWEET PULL 28
# 08:09
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
#
# TWEET PULL 29
# 08:09
# lmao bro its sick how raw that mf is lol gucci n moncler raw racist yes but also raw 😂
# -0.0010989010989011043
# neutral
# lmao bro its sick how raw that mf is lol gucci n moncler raw racist yes but also raw 😂
# -0.0010989010989011043
# neutral
# TWEET PULL 30
# 08:09
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# pos
# TWEET PULL 31
# 08:09
# RT This is disgusting Wtf is this!
# -0.8125
# neg
# 08:09
# Prada Gucci Moncler.. you are Cut in my eyes https://t.co/NOWeXYLOGr
# 0.0
# neutral
# RT This is disgusting Wtf is this!
# -0.8125
# neg
# Prada Gucci Moncler.. you are Cut in my eyes https://t.co/NOWeXYLOGr
# 0.0
# neutral
# TWEET PULL 32
# 08:10
# Most of yal Gucci came from the same place you get your hair and Durag’s so don’t feel bad....
# -0.06666666666666661
# neg
#
# TWEET PULL 33
# 08:11
# RT _ ALOT OF THAT GUCCI YALL SAYING YALL NOT WEARING NOMORE WAS FAKE ANYWAY
# -0.5
# neg
#
# TWEET PULL 34
# 08:12
# RT 0 goals 0 assists the streets will remember https://t.co/iL8slnyEuA
# 0.0
# neutral
#
# TWEET PULL 35
# 08:14
# RT Instead of simply boycotting #Gucci I’d recommend supporting Black-owned luxury brands like #FearofGod by Jerry Lorenzo a…
# 0.125
# neutral
#
# TWEET PULL 36
# 08:14
# RT _ They been boycotting lmao https://t.co/78WrJcrfbc
# 0.6
# pos
# RT _ They been boycotting lmao https://t.co/78WrJcrfbc
# 0.6
# pos
# TWEET PULL 37
# 08:17
# Looking for a shirt/pant idea Reply with shirt ideas, Rules.
# 0.0
# neutral
# 08:17
# 1 Not dull one color/stripes etc.
# 0.14583333333333334
# neutral
# 08:17
# 2 Must have a br https://t.co/1nWw3ZMgyS
# 0.0
# neutral
#
# TWEET PULL 38
# 08:18
# RT Y’all don’t even own Gucci to be boycotting that shit 🤣
# 0.19999999999999998
# neutral
#
# TWEET PULL 39
# 08:18
# RT CEO Of Gucci Will Meet With Dapper Dan To Discuss ‘Blackface Controversy [PHOTO https://t.co/eD7UZpS2a6 https://t.co/EHlJ3G4Ett
# 0.0
# neutral
# RT CEO Of Gucci Will Meet With Dapper Dan To Discuss ‘Blackface Controversy [PHOTO https://t.co/eD7UZpS2a6 https://t.co/EHlJ3G4Ett
# 0.0
# neutral
# TWEET PULL 40
# 08:18
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# pos
# TWEET PULL 41
# 08:18
# RT Celebrity "Don't give your money to Gucci until they hire Black designers.
# -0.16666666666666666
# neg
# 08:18
# How about you give your money directly to Black…
# 0.1
# neutral
# RT Celebrity "Don't give your money to Gucci until they hire Black designers.
# -0.16666666666666666
# neg
# How about you give your money directly to Black…
# 0.1
# pos
# TWEET PULL 42
# 08:18
# So many high end designers with so much good drip I been was over Gucci and Prada shit is water down and everyone look the same —
# 0.16740740740740737
# neutral
# So many high end designers with so much good drip I been was over Gucci and Prada shit is water down and everyone look the same —
# 0.16740740740740737
# pos
# TWEET PULL 43
# 08:19
# RT _ They been boycotting lmao https://t.co/78WrJcrfbc
# 0.6
# pos
#
# TWEET PULL 44
# 08:21
# Wait I'm sorry did Gucci really have to publicly apologize for making half of a ski mask in their brand... You do https://t.co/tLsy0ZbcXU
# -0.11666666666666667
# neg
#
# TWEET PULL 45
# 08:22
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
#
# TWEET PULL 46
# 08:23
# RT T.I Let’s boycott Gucci for 3 months Me knowing I never bought any Gucci in my life https://t.co/YGD23VWVFA
# 0.0
# neutral
#
# TWEET PULL 47
# 08:26
# RT T.I Let’s boycott Gucci for 3 months Me knowing I never bought any Gucci in my life https://t.co/YGD23VWVFA
# 0.0
# neutral
#
# TWEET PULL 48
# 08:28
# The only way Blacks will stop buying Gucci and etc if a black person brought the company...
# -0.08333333333333333
# neg
#
# TWEET PULL 49
# 08:28
# RT this gucci boycott is wild easy so i'm with it
# 0.26666666666666666
# neutral
# RT this gucci boycott is wild easy so i'm with it
# 0.26666666666666666
# pos
# TWEET PULL 50
# 08:32
# RT T.I Let’s boycott Gucci for 3 months Me knowing I never bought any Gucci in my life https://t.co/YGD23VWVFA
# 0.0
# neutral
#
# TWEET PULL 51
# 08:32
# Action packed ep 🤲🏽
# 0.1
# neutral
# Action packed ep 🤲🏽
# 0.1
# pos
# TWEET PULL 52
# 08:32
# RT I UNDERSTAND GUCCI IS CANCELED AND I AGREE IT SHOULD BE❗️....BUT DONT BE THE NUMBER 1 AMBASSADOR WHEN YOU KNOW YOU CANT AFFOR…
# 0.0
# neutral
# RT I UNDERSTAND GUCCI IS CANCELED AND I AGREE IT SHOULD BE❗️....BUT DONT BE THE NUMBER 1 AMBASSADOR WHEN YOU KNOW YOU CANT AFFOR…
# 0.0
# neutral
# TWEET PULL 53
# 08:34
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
#
# TWEET PULL 54
# 08:35
# Someone asked Beyonc was she gonna boycott Gucci 🤔🤔🤔
# 0.0
# neutral
#
# TWEET PULL 55
# 08:37
# Gucci got what they wanted free advertising because of a bigot like you making a fuss dick head.
# 0.4
# pos
#
# TWEET PULL 56
# 08:38
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
#
# TWEET PULL 57
# 08:39
# RT T.I Let’s boycott Gucci for 3 months Me knowing I never bought any Gucci in my life https://t.co/YGD23VWVFA
# 0.0
# neutral
#
# TWEET PULL 58
# 08:40
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
#
# TWEET PULL 59
# 08:40
# RT If y'all cancelling Gucci don't forget Moncler too ☺ https://t.co/x8QMovnBUF
# 0.0
# neutral
# RT If y'all cancelling Gucci don't forget Moncler too ☺ https://t.co/x8QMovnBUF
# 0.0
# neutral
# TWEET PULL 60
# 08:40
# RT Pyer moss Stella jean public school a coldwall want less essentials walled Bonner...........all black owned luxury bran…
# -0.1111111111111111
# neg
# RT Pyer moss Stella jean public school a coldwall want less essentials walled Bonner...........all black owned luxury bran…
# -0.1111111111111111
# neg
# TWEET PULL 61
# 08:41
# RT Nah nigga’s face after that gucci flip flop line He’s hurt https://t.co/h802Kmtkxn
# 0.0
# neutral
#
# TWEET PULL 62
# 08:42
# RT _ They been boycotting lmao https://t.co/78WrJcrfbc
# 0.6
# pos
#
# TWEET PULL 63
# 08:45
# RT cardio good for the heart https://t.co/pp9DZHzSVc
# 0.7
# pos
#
# TWEET PULL 64
# 08:45
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# pos
# TWEET PULL 65
# 08:46
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
#
# TWEET PULL 66
# 08:46
# better idea Buy ME gucci!
# 0.625
# pos
# better idea Buy ME gucci!
# 0.625
# pos
# TWEET PULL 67
# 08:47
# RT I UNDERSTAND GUCCI IS CANCELED AND I AGREE IT SHOULD BE❗️....BUT DONT BE THE NUMBER 1 AMBASSADOR WHEN YOU KNOW YOU CANT AFFOR…
# 0.0
# neutral
#
# TWEET PULL 68
# 08:48
# Rich black folks BOYCOTT GUCCI AND PRADA!
# 0.08333333333333334
# neutral
# 08:48
# Working class black folks bruh I've never even owned any of their products.
# -0.16666666666666666
# neg
# 08:48
# 🤷🏾‍♂️
# 0.0
# neutral
#
# TWEET PULL 69
# 08:48
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# pos
# TWEET PULL 70
# 08:49
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
#
# TWEET PULL 71
# 08:49
# RT The real king of the industry tbh https://t.co/IiGGMWlFbi
# 0.2
# neutral
# RT The real king of the industry tbh https://t.co/IiGGMWlFbi
# 0.2
# pos
# TWEET PULL 72
# 08:50
# RT 19 Black Owned Luxury Brands To Support Instead of GUCCI and Prada https://t.co/GcDLuqUmiN
# -0.16666666666666666
# neg
#
# TWEET PULL 73
# 08:53
# RT Lee took to Instagram to proclaim he is officially boycotting Prada and Gucci until they “hire some Black designers to be in…
# -0.16666666666666666
# neg
#
# TWEET PULL 74
# 08:53
# RT This is disgusting Wtf is this!
# -0.8125
# neg
# 08:53
# Prada Gucci Moncler.. you are Cut in my eyes https://t.co/NOWeXYLOGr
# 0.0
# neutral
# RT This is disgusting Wtf is this!
# -0.8125
# neg
# Prada Gucci Moncler.. you are Cut in my eyes https://t.co/NOWeXYLOGr
# 0.0
# neutral
# TWEET PULL 75
# 08:56
# Me "What's up bro How you been?
# 0.0
# neutral
# 08:56
# Homeboy "I'm gucci fam."
# 0.0
# neutral
# 08:56
# Me "That bad huh?
# -0.6999999999999998
# neg
# 08:56
# "Well hang in there bro shit will get better for you."
# 0.15
# neutral
#
# TWEET PULL 76
# 09:02
# What’s a Gucci
# 0.0
# neutral
#
# TWEET PULL 77
# 09:05
# RT Gucci S/S 2019 campaign inspired by Hollywood’s musical https://t.co/oja4XcwMd4
# 0.0
# neutral
#
# TWEET PULL 78
# 09:05
# RT This is disgusting Wtf is this!
# -0.8125
# neg
# 09:05
# Prada Gucci Moncler.. you are Cut in my eyes https://t.co/NOWeXYLOGr
# 0.0
# neutral
# RT This is disgusting Wtf is this!
# -0.8125
# neg
# Prada Gucci Moncler.. you are Cut in my eyes https://t.co/NOWeXYLOGr
# 0.0
# neutral
# TWEET PULL 79
# 09:08
# RT This is disgusting Wtf is this!
# -0.8125
# neg
# 09:08
# Prada Gucci Moncler.. you are Cut in my eyes https://t.co/NOWeXYLOGr
# 0.0
# neutral
#
# TWEET PULL 80
# 09:11
# RT T.I Let’s boycott Gucci for 3 months Me knowing I never bought any Gucci in my life https://t.co/YGD23VWVFA
# 0.0
# neutral
#
# TWEET PULL 81
# 09:12
# RT Nah nigga’s face after that gucci flip flop line He’s hurt https://t.co/h802Kmtkxn
# 0.0
# neutral
#
# TWEET PULL 82
# 09:14
# RT Nah nigga’s face after that gucci flip flop line He’s hurt https://t.co/h802Kmtkxn
# 0.0
# neutral
#
# TWEET PULL 83
# 09:14
# RT he was literally flexing with his gucci stuff.
# 0.0
# neutral
# 09:14
# boy u better come through and post a photo holding the grammy invitation ht…
# 0.5
# pos
# RT he was literally flexing with his gucci stuff.
# 0.0
# neutral
# boy u better come through and post a photo holding the grammy invitation ht…
# 0.5
# pos
# TWEET PULL 84
# 09:14
# How yall gone tell us broke niggas to boycott Prada Gucci and moncler ....if we can't even afford the shit in th https://t.co/O6x2o8dQGt
# -0.2
# neg
# How yall gone tell us broke niggas to boycott Prada Gucci and moncler ....if we can't even afford the shit in th https://t.co/O6x2o8dQGt
# -0.2
# neg
# TWEET PULL 85
# 09:14
# RT Y’all need to boycott that inspired fake Gucci
# -0.5
# neg
# RT Y’all need to boycott that inspired fake Gucci
# -0.5
# neg
# TWEET PULL 86
# 09:16
# .. &amp &amp &amp &amp has always been Down w/ https://t.co/PwGddZAGJj
# -0.15555555555555559
# neg
#
# TWEET PULL 87
# 09:16
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# pos
# TWEET PULL 88
# 09:16
# RT T.I Let’s boycott Gucci for 3 months Me knowing I never bought any Gucci in my life https://t.co/YGD23VWVFA
# 0.0
# neutral
# RT T.I Let’s boycott Gucci for 3 months Me knowing I never bought any Gucci in my life https://t.co/YGD23VWVFA
# 0.0
# neutral
# TWEET PULL 89
# 09:17
# RT _ Lil baby really said “if she tell me no once I won’t even touch it he raising anti rape awareness while ur guys favorit…
# 0.2
# neutral
#
# TWEET PULL 90
# 09:17
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# pos
# TWEET PULL 91
# 09:18
# If you Never owned GUCCI,PRADA,OR MONCLER you can’t boycott it a wallet don’t count either
# 0.0
# neutral
#
# TWEET PULL 92
# 09:19
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
#
# TWEET PULL 93
# 09:20
# RT _ ALOT OF THAT GUCCI YALL SAYING YALL NOT WEARING NOMORE WAS FAKE ANYWAY
# -0.5
# neg
#
# TWEET PULL 94
# 09:22
# RT “When You Just Bought Hella Gucci But They Canceled https://t.co/qJ2m2X5ox9
# 0.0
# neutral
#
# TWEET PULL 95
# 09:24
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
#
# TWEET PULL 96
# 09:24
# I’m highly disappointed.
# -0.75
# neg
# I’m highly disappointed.
# -0.75
# neg
# TWEET PULL 97
# 09:24
# RT These faux pas just keep getting funnier and funnier I’m still laughing about H&amp;M’s jungle T-shirt https://t.co/zAELIo5…
# 0.0
# neutral
# RT These faux pas just keep getting funnier and funnier I’m still laughing about H&amp;M’s jungle T-shirt https://t.co/zAELIo5…
# 0.0
# neutral
# TWEET PULL 98
# 09:24
# RT _ ALOT OF THAT GUCCI YALL SAYING YALL NOT WEARING NOMORE WAS FAKE ANYWAY
# -0.5
# neg
# RT _ ALOT OF THAT GUCCI YALL SAYING YALL NOT WEARING NOMORE WAS FAKE ANYWAY
# -0.5
# neg
# TWEET PULL 99
# 09:25
# RT Nah nigga’s face after that gucci flip flop line He’s hurt https://t.co/h802Kmtkxn
# 0.0
# neutral
#
# TWEET PULL 100
# 09:26
# RT T.I Let’s boycott Gucci for 3 months Me knowing I never bought any Gucci in my life https://t.co/YGD23VWVFA
# 0.0
# neutral
#
# TWEET PULL 101
# 09:26
# RT This is disgusting Wtf is this!
# -0.8125
# neg
# 09:26
# Prada Gucci Moncler.. you are Cut in my eyes https://t.co/NOWeXYLOGr
# 0.0
# neutral
# RT This is disgusting Wtf is this!
# -0.8125
# neg
# Prada Gucci Moncler.. you are Cut in my eyes https://t.co/NOWeXYLOGr
# 0.0
# neutral
# TWEET PULL 102
# 09:27
# RT 19 Black Owned Luxury Brands To Support Instead of GUCCI and Prada https://t.co/5Zf6UuIc2B
# -0.16666666666666666
# neg
#
# TWEET PULL 103
# 09:28
# RT Nah nigga’s face after that gucci flip flop line He’s hurt https://t.co/h802Kmtkxn
# 0.0
# neutral
#
# TWEET PULL 104
# 09:28
# RT gucci tennis shoes running from your issues
# 0.0
# neutral
# RT gucci tennis shoes running from your issues
# 0.0
# neutral
# TWEET PULL 105
# 09:28
# RT Looking for a shirt/pant idea Reply with shirt ideas, Rules.
# 0.0
# neutral
# 09:28
# 1 Not dull one color/stripes etc.
# 0.14583333333333334
# neutral
# 09:28
# 2 Must have a brand…
# 0.0
# neutral
# RT Looking for a shirt/pant idea Reply with shirt ideas, Rules.
# 0.0
# neutral
# 1 Not dull one color/stripes etc.
# 0.14583333333333334
# pos
# 2 Must have a brand…
# 0.0
# neutral
# TWEET PULL 106
# 09:28
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# pos
# TWEET PULL 107
# 09:29
# T.I and Soulja Boy Call for Boycott Against Gucci Following Blackface Controversy https://t.co/biUIA55iya
# 0.0
# neutral
#
# TWEET PULL 108
# 09:29
# RT I UNDERSTAND GUCCI IS CANCELED AND I AGREE IT SHOULD BE❗️....BUT DONT BE THE NUMBER 1 AMBASSADOR WHEN YOU KNOW YOU CANT AFFOR…
# 0.0
# neutral
# RT I UNDERSTAND GUCCI IS CANCELED AND I AGREE IT SHOULD BE❗️....BUT DONT BE THE NUMBER 1 AMBASSADOR WHEN YOU KNOW YOU CANT AFFOR…
# 0.0
# neutral
# TWEET PULL 109
# 09:29
# RT _kwu Yall boycotting Gucci because of black face, yet they painted Christ face White &amp Nobody is boycotting Christianity 👀☕.
# -0.08333333333333333
# neg
# RT _kwu Yall boycotting Gucci because of black face, yet they painted Christ face White &amp Nobody is boycotting Christianity 👀☕.
# -0.08333333333333333
# neg
# TWEET PULL 110
# 09:31
# RT This is disgusting Wtf is this!
# -0.8125
# neg
# 09:31
# Prada Gucci Moncler.. you are Cut in my eyes https://t.co/NOWeXYLOGr
# 0.0
# neutral
#
# TWEET PULL 111
# 09:33
# Same
# 0.0
# neutral
#
# TWEET PULL 112
# 09:33
# RT _ I’m highly disappointed.
# -0.75
# neg
# RT _ I’m highly disappointed.
# -0.75
# neg
# TWEET PULL 113
# 09:34
# RT T.I Let’s boycott Gucci for 3 months Me knowing I never bought any Gucci in my life https://t.co/YGD23VWVFA
# 0.0
# neutral
#
# TWEET PULL 114
# 09:35
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
#
# TWEET PULL 115
# 09:36
# I’m voting for #QueenNaija for the #SOCIALSTARAWARD at the #iHeartAwards RT to vote too 💋
# 0.0
# neutral
#
# TWEET PULL 116
# 09:36
# What’s Gucci
# 0.0
# neutral
# What’s Gucci
# 0.0
# neutral
# TWEET PULL 117
# 09:37
# RT T.I Let’s boycott Gucci for 3 months Me knowing I never bought any Gucci in my life https://t.co/YGD23VWVFA
# 0.0
# neutral
#
# TWEET PULL 118
# 09:37
# RT T.I Let’s boycott Gucci for 3 months Me knowing I never bought any Gucci in my life https://t.co/YGD23VWVFA
# 0.0
# neutral
# RT T.I Let’s boycott Gucci for 3 months Me knowing I never bought any Gucci in my life https://t.co/YGD23VWVFA
# 0.0
# neutral
# TWEET PULL 119
# 09:38
# RT ✊ this #BlackHistoryMonth has been ass backwards Why in 2000 anything you would think the #BlackFace was ok Th…
# 0.5
# pos
#
# TWEET PULL 120
# 09:39
# Yet y’all still wear it
# 0.0
# neutral
#
# TWEET PULL 121
# 09:39
# #NowPlaying So Icy by Gucci Mane 😂😭 this is my phone on shuffle people hahaha
# 0.05
# neutral
# #NowPlaying So Icy by Gucci Mane 😂😭 this is my phone on shuffle people hahaha
# 0.05
# pos
# TWEET PULL 122
# 09:39
# RT If y'all cancelling Gucci don't forget Moncler too ☺ https://t.co/x8QMovnBUF
# 0.0
# neutral
# RT If y'all cancelling Gucci don't forget Moncler too ☺ https://t.co/x8QMovnBUF
# 0.0
# neutral
# TWEET PULL 123
# 09:39
# 😭 I’m voting for #QueenNaija for the #SOCIALSTARAWARD at the #iHeartAwards RT to vote too!
# 0.0
# neutral
# 😭 I’m voting for #QueenNaija for the #SOCIALSTARAWARD at the #iHeartAwards RT to vote too!
# 0.0
# neutral
# TWEET PULL 124
# 09:40
# RT These brands on top of having no clear concept of what is and is not offensive content are trying to Copy the Patrick Ke…
# 0.225
# neutral
#
# TWEET PULL 125
# 09:40
# Right Won’t support black business but gets DISRESPECTED by a w https://t.co/D66botevMW
# 0.05952380952380952
# neutral
# Right Won’t support black business but gets DISRESPECTED by a w https://t.co/D66botevMW
# 0.05952380952380952
# pos
# TWEET PULL 126
# 09:40
# not you now💀
# 0.0
# neutral
# not you now💀
# 0.0
# neutral
# TWEET PULL 127
# 09:40
# What's the bullet points of this meeting with this (Dog) CEO?!
# 0.0
# neutral
# 09:40
# This person know https://t.co/R7UJEW853y
# 0.0
# neutral
# What's the bullet points of this meeting with this (Dog) CEO?!
# 0.0
# neutral
# This person know https://t.co/R7UJEW853y
# 0.0
# neutral
# TWEET PULL 128
# 09:40
# OOP PERIODT THE KING HAS SPOKE.
# 0.0
# neutral
# OOP PERIODT THE KING HAS SPOKE.
# 0.0
# neutral
# TWEET PULL 129
# 09:40
# RT Gucci deeply apologizes for the offense caused by the wool balaclava jumper.
# 0.0
# neutral
# 09:40
# We consider diversity to be a fundamental value to…
# 0.0
# neutral
# RT Gucci deeply apologizes for the offense caused by the wool balaclava jumper.
# 0.0
# neutral
# We consider diversity to be a fundamental value to…
# 0.0
# neutral
# TWEET PULL 130
# 09:41
# was this the inspo 🤔👀
# 0.0
# neutral
#
# TWEET PULL 131
# 09:43
# RT Nah nigga’s face after that gucci flip flop line He’s hurt https://t.co/h802Kmtkxn
# 0.0
# neutral
#
# TWEET PULL 132
# 09:44
# RT Nah nigga’s face after that gucci flip flop line He’s hurt https://t.co/h802Kmtkxn
# 0.0
# neutral
#
# TWEET PULL 133
# 09:44
# RT _ I’m highly disappointed.
# -0.75
# neg
# RT _ I’m highly disappointed.
# -0.75
# neg
# TWEET PULL 134
# 09:44
# Yes king 👏🏽👏🏽👏🏽👏🏽👏🏽🙌🏽🙌🏽
# 0.0
# neutral
# Yes king 👏🏽👏🏽👏🏽👏🏽👏🏽🙌🏽🙌🏽
# 0.0
# neutral
# TWEET PULL 135
# 09:45
# RT Soulja Boy Says He's Done with Gucci After Blackface Scandal https://t.co/xf6ZMLQjme
# 0.0
# neutral
#
# TWEET PULL 136
# 09:45
# Find some black owned businesses!
# -0.20833333333333331
# neg
# Find some black owned businesses!
# -0.20833333333333331
# neg
# TWEET PULL 137
# 09:45
# RT _ I’m highly disappointed.
# -0.75
# neg
# RT _ I’m highly disappointed.
# -0.75
# neg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-348a7bdff26c> in <module>
#       1 while True:
#       2     try:
# ----> 3         stream.filter(track=[brand], languages=["en"]);
#       4
#       5     except (ProtocolError, AttributeError):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     317             length = 0
#     318             while not resp.raw.closed:
# --> 319                 line = buf.read_line()
#     320                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     321                 if not stripped_line:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     411             else:
#     412                 cache_content = False
# --> 413                 data = self._fp.read(amt)
#     414                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     415                     # Close the connection when no data is returned
#
# C:\ProgramData\Anaconda3\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# C:\ProgramData\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# C:\ProgramData\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# C:\ProgramData\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
